# %% [markdown]
# # IPL Data Analysis

# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns
mlt.style.use('fivethirtyeight')

# %%
#importing the dataset
dataset1 = pd.read_csv('ball_by_ball_data.csv')
dataset2 = pd.read_csv('key_teams.csv')
dataset3 = pd.read_csv('match_data.csv')
dataset4 = pd.read_csv('player_rosters.csv')
dataset5 = pd.merge(dataset1, dataset3, on='match_id')

# %%
#total match played
print('Total Matches Played:',dataset3.shape[0])
print(' \n Venues Played At:',dataset3['city'].unique())     
print(' \n Teams :',dataset3['team1_id'].unique())
# Out:
# Total Matches Played: 636
#
#  Venues Played At: ['Bangalore' 'Chandigarh' 'Delhi' 'Mumbai' 'Kolkata' 'Jaipur' 'Hyderabad'
#  'Chennai' 'Cape Town' 'Port Elizabeth' 'Durban' 'Centurion' 'East London'
#  'Johannesburg' 'Kimberley' 'Bloemfontein' 'Ahmedabad' 'Cuttack' 'Nagpur'
#  'Dharamsala' 'Kochi' 'Indore' 'Visakhapatnam' 'Pune' 'Raipur' 'Ranchi'
#  'Abu Dhabi' 'Sharjah' nan 'Rajkot' 'Kanpur']
#
#  Teams : ['KKR' 'CSK' 'RR' 'MI' 'DC' 'KXI' 'RCB' 'DD' 'KTK' 'PW' 'SRH' 'RPS' 'GL']

# %%
#total venues where matches are played
print('Total venues played at:',dataset3['city'].nunique())
# Out:
# Total venues played at: 30

# %%
#win by max runs
df=dataset3.iloc[[dataset3['win_by_runs'].idxmax()]]
df[['season','team1_id','team2_id','winner','win_by_runs']]
# Out:
#      season team1_id team2_id winner  win_by_runs
# 620    2017       MI       DD     MI          146

# %%
#matches run by least run
dataset3[dataset3.win_by_runs>0].win_by_runs.min()
# Out:
# 1

# %%
#max win by wicket.
df=dataset3.iloc[[dataset3['win_by_wickets'].idxmax()]]
df[['season','team1_id','team2_id','winner','win_by_wickets']]
# Out:
#     season team1_id team2_id winner  win_by_wickets
# 12    2008       MI       DC     DC              10

# %%
# man of the match awards
dataset3['player_of_match'].value_counts()
# Out:
# Chris Gayle             18
# Yusuf Pathan            16
# David Warner            15
# AB De Villiers          15
# Rohit Sharma            14
# Suresh Raina            14
# Gautam Gambhir          13
# Mahendra Singh Dhoni    13
# Michael Hussey          12
# Ajinkya Rahane          12
# Dwayne Smith            11
# Virender Sehwag         11
# Virat Kohli             11
# Shane Watson            10
# Jacques Kallis          10
# Kieron Pollard           9
# Amit Mishra              9
# Shaun Marsh              9
# Sachin Tendulkar         8
# Ravindra Jadeja          7
# Adam Gilchrist           7
# Ambati Rayudu            7
# Robin Uthappa            7
# Sunil Narine             6
# Andre Russell            6
# Umesh Yadav              6
# Murali Vijay             6
# Ashish Nehra             6
# Harbhajan Singh          6
# Brad Hodge               6
#                         ..
# Herschelle Gibbs         1
# Marlon Samuels           1
# Umar Gul                 1
# Paul Collingwood         1
# Rajat Bhatia             1
# Bhargav Bhatt            1
# Mohammed Shami           1
# Mitchell Starc           1
# S Badrinath              1
# Tirumalsetti Suman       1
# Mitchell Marsh           1
# Angelo Mathews           1
# Nuwan Kulasekara         1
# RP Singh                 1
# Aditya Tare              1
# Dilhara Fernando         1
# Michael Lumb             1
# Farveez Maharoof         1
# Washington Sunder        1
# Dirk Nannes              1
# Jos Buttler              1
# Carlos Brathwaite        1
# George Bailey            1
# Ravichandran Ashwin      1
# Manpreet Gony            1
# Mohnish Mishra           1
# Jesse Ryder              1
# Rahul Tripathi           1
# Manvinder Bisla          1
# Yuzvendra Chahal         1
# Name: player_of_match, dtype: int64

# %%
# percent of decisoin for batting/bowling after toss win
print('Toss Decisions in %\n',((dataset3['toss_decision']).value_counts())/636*100)
# Out:
# Toss Decisions in %
#  field    57.075472
# bat      42.924528
# Name: toss_decision, dtype: float64

# %%
#total no. of super over
dataset1[dataset1['is_super_over']==1]['match_id'].nunique()
# Out:
# 7

# %%
#percent when toss winner is winner according to teams
dataset3[dataset3['toss_winner']==dataset3['winner']]['winner'].value_counts()/dataset3['toss_winner'].value_counts()
# Out:
# CSK    0.636364
# DC     0.441860
# DD     0.458333
# GL     0.666667
# KKR    0.564103
# KTK    0.500000
# KXI    0.411765
# MI     0.564706
# PW     0.150000
# RCB    0.500000
# RPS    0.615385
# RR     0.539683
# SRH    0.485714
# dtype: float64

# %%
#no. of times each team win toss
mlt.subplots(figsize=(10,6))
ax=dataset3['toss_winner'].value_counts().plot.bar(width=0.8)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))
mlt.show()

# %%
#no. of matches in each season 
mlt.subplots(figsize=(10,6))
sns.countplot(x='season',data=dataset3,palette="Set1")  #countplot automatically counts the frequency of an item
mlt.show()

# %%
#no. of runs each season
mlt.subplots(figsize=(10,6))
batsmen = dataset3[['match_id','season']].merge(dataset1, left_on = 'match_id', right_on = 'match_id', how = 'left')
#merging the matches and delivery dataframe by referencing the id and match_id columns respectively
batsmen['total_runs']=batsmen['batsman_runs']+batsmen ['extra_runs']
season=batsmen.groupby(['season'])['total_runs'].sum().reset_index()
season['total_runs'].plot(marker='o')
mlt.show()

# %%
#matches each season
matches_each_season=dataset3.groupby(['season']).count().match_id.reset_index()
matches_each_season
# Out:
#    season  match_id
# 0    2008        58
# 1    2009        57
# 2    2010        60
# 3    2011        73
# 4    2012        74
# 5    2013        76
# 6    2014        60
# 7    2015        59
# 8    2016        60
# 9    2017        59

# %%
#matches won by runs
dataset3['win_by_runs'].astype(bool).sum(axis=0)
# Out:
# 287

# %%
# avg runs of all teams when they bat first
dataset1['total_runs']= dataset1['batsman_runs']+dataset1['extra_runs']
xyz=dataset1.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index() 
xyz.drop('match_id',axis=1,inplace=True) 
xyz = xyz.groupby(['inning','batting_team'])['total_runs'].mean().reset_index()
innings_one = xyz[xyz['inning']==1]
innings_one.drop('inning',axis=1,inplace=True)
innings_one
# Out:
# C:\Users\abhinav tyagi\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    batting_team  total_runs
# 0           CSK  164.844156
# 1            DC  157.325581
# 2            DD  152.777778
# 3            GL  161.928571
# 4           KKR  155.029412
# 5           KTK  144.142857
# 6           KXI  159.584416
# 7            MI  163.256098
# 8            PW  148.650000
# 9           RCB  167.214286
# 10          RPS  161.800000
# 11           RR  156.851852
# 12          SRH  160.782609

# %%
#avg runs per match of all teams when they bat second
dataset1['total_runs']= dataset1['batsman_runs']+dataset1['extra_runs'] 
xyz=dataset1.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index() 
xyz.drop('match_id',axis=1,inplace=True) 
xyz = xyz.groupby(['inning','batting_team'])['total_runs'].mean().reset_index() 
innings_two = xyz[xyz['inning']==2] 
innings_two.drop('inning',axis=1,inplace=True) 
innings_two
# Out:
# C:\Users\abhinav tyagi\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    batting_team  total_runs
# 13          CSK  151.796296
# 14           DC  146.812500
# 15           DD  146.630952
# 16           GL  161.812500
# 17          KKR  142.462500
# 18          KTK  127.428571
# 19          KXI  151.478873
# 20           MI  148.306667
# 21           PW  135.400000
# 22          RCB  142.695122
# 23          RPS  140.400000
# 24           RR  146.000000
# 25          SRH  141.200000

# %%
#matches won by teams
dataset3['winner'].value_counts()
# Out:
# MI     92
# CSK    79
# KKR    77
# RCB    73
# KXI    70
# RR     63
# DD     62
# SRH    42
# DC     29
# RPS    15
# GL     13
# PW     12
# KTK     6
# Name: winner, dtype: int64

# %%
#avg run per run in each season
season['total_runs']/matches_each_season ['match_id']
# Out:
# 0    309.258621
# 1    286.894737
# 2    314.716667
# 3    289.780822
# 4    303.418919
# 5    297.394737
# 6    315.516667
# 7    311.067797
# 8    314.366667
# 9    318.406780
# dtype: float64

# %%
# season wise winner.
for i in range(2008,2017):
 df=((dataset3[dataset3['season']==i]).iloc[-1]) 
 print(df[[1,10]])
# Out:
# season    2008
# winner      RR
# Name: 57, dtype: object
# season    2009
# winner      DC
# Name: 114, dtype: object
# season    2010
# winner     CSK
# Name: 174, dtype: object
# season    2011
# winner     CSK
# Name: 247, dtype: object
# season    2012
# winner     KKR
# Name: 321, dtype: object
# season    2013
# winner      MI
# Name: 397, dtype: object
# season    2014
# winner     KKR
# Name: 457, dtype: object
# season    2015
# winner      MI
# Name: 516, dtype: object
# season    2016
# winner     SRH
# Name: 576, dtype: object

# %%
#boundries across seasons
data=pd.DataFrame()
sixes=dataset5.groupby('season')['batsman_runs'].apply(lambda x:(x==6).sum())
fours=dataset5.groupby('season')['batsman_runs'].apply(lambda x:(x==4).sum())
boundries=pd.DataFrame({'season':sixes.index,'6':sixes.values})
boundries['4']=fours.values
boundries
boundries[['6','4']].plot(marker='o')
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %% [markdown]
# ## Batting Analysis

# %%
# total batsman runs as per match
batsman1=dataset1.groupby(['match_id','batsman'])['batsman_runs'].sum().reset_index()

# %%
dataset1['batsman_']=dataset1['batsman']

# %%
#total match balls as per match
batsman2=dataset1.groupby(['match_id','batsman_'])['batsman'].count().reset_index()
batsman2=batsman2.rename(columns={'batsman':'balls'}) 
batsman2=batsman2.rename(columns={'match_id':'matchid__'})

# %%
#joining the two
batsman1 = pd.concat([batsman1, batsman2], axis=1, join='inner')

# %%
batsman1=batsman1.drop('batsman_', axis=1)
batsman1=batsman1.drop('matchid__', axis=1)
batsman1.head()
# Out:
#   match_id            batsman  batsman_runs  balls
# 0   2008_1      Ashley Noffke             9     12
# 1   2008_1  Balachandra Akhil             0      2
# 2   2008_1   Brendon McCullum           158     77
# 3   2008_1      Cameron White             6     10
# 4   2008_1       David Hussey            12     12

# %%
hundreds=batsman1[batsman1['batsman_runs']>100]

# %%
fifties=batsman1[(batsman1['batsman_runs']<100 )& (batsman1['batsman_runs']>=50)]

# %%
#All hundreds in IPL
hundreds
# Out:
#      match_id             batsman  batsman_runs  balls
# 2      2008_1    Brendon McCullum           158     77
# 67    2008_13      Adam Gilchrist           109     50
# 179    2008_2      Michael Hussey           116     54
# 465   2008_37   Sanath Jayasuriya           114     53
# 478   2008_38         Shaun Marsh           115     72
# 868    2008_9      Andrew Symonds           117     57
# 1638  2009_54       Manish Pandey           114     74
# 1723   2009_8      AB De Villiers           105     54
# 2041  2010_26        David Warner           107     72
# 2153  2010_32        Murali Vijay           127     57
# 2180  2010_34  Mahela Jayawardene           110     61
# 2909  2011_24         Chris Gayle           102     57
# 3262  2011_45     Virender Sehwag           119     58
# 3269  2011_46         Chris Gayle           107     49
# 3537  2011_62      Adam Gilchrist           106     58
# 3722   2011_9       Paul Valthaty           120     64
# 3850  2012_16     Kevin Pietersen           103     66
# 3892  2012_19      Ajinkya Rahane           103     60
# 3974  2012_24        David Warner           109     55
# 4491  2012_56        Rohit Sharma           109     62
# 4634  2012_65         Chris Gayle           128     62
# 4780  2012_73        Murali Vijay           113     61
# 5172  2013_29        Shane Watson           101     64
# 5199  2013_30         Chris Gayle           175     69
# 5786  2013_67        David Miller           101     39
# 6793  2014_59     Virender Sehwag           122     62
# 6822  2014_60     Wriddhiman Saha           115     56
# 7387  2015_40         Chris Gayle           117     63
# 7455  2015_45      AB De Villiers           133     61
# 7596  2015_53        Shane Watson           104     62
# 7785  2016_11     Quinton de Kock           108     54
# 7995  2016_25        Steven Smith           101     54
# 8159  2016_35         Virat Kohli           108     58
# 8288  2016_44      AB De Villiers           129     53
# 8302  2016_44         Virat Kohli           109     55
# 8390  2016_50         Virat Kohli           113     51
# 8838  2017_22         Hashim Amla           104     63
# 9058  2017_36        David Warner           126     60
# 9088  2017_38          Ben Stokes           103     64
# 9231  2017_46         Hashim Amla           104     61
# 9514   2017_9        Sanju Samson           102     64

# %%
# All 150+ in IPL
one50s=batsman1[batsman1['batsman_runs']>150]
one50s
# Out:
#      match_id           batsman  batsman_runs  balls
# 2      2008_1  Brendon McCullum           158     77
# 5199  2013_30       Chris Gayle           175     69

# %%
#All nervous 90s in IPL
nervous90s=batsman1[(batsman1['batsman_runs']>=90) &( batsman1['batsman_runs']<100)]
nervous90s
# Out:
#      match_id             batsman  batsman_runs  balls
# 24    2008_10    Kumar Sangakkara            94     58
# 407   2008_33      Sourav Ganguly            91     58
# 696   2008_51        Graeme Smith            91     52
# 849    2008_7     Virender Sehwag            94     43
# 1092  2009_20        Suresh Raina            98     57
# 1790  2010_11      Matthew Hayden            93     46
# 2154  2010_32          Naman Ojha            94     57
# 2470  2010_51  Mahela Jayawardene            93     65
# 2925  2011_25         Shaun Marsh            95     47
# 3600  2011_66      Shikhar Dhawan            95     59
# 3703  2011_73        Murali Vijay            95     53
# 4173  2012_37      Gautam Gambhir            93     54
# 4213   2012_4      Ajinkya Rahane            98     72
# 4421  2012_51        Shane Watson            90     51
# 5010   2013_2         Chris Gayle            92     61
# 5150  2013_27     Virender Sehwag            95     57
# 5277  2013_35        Shane Watson            98     53
# 5303  2013_37     Manvinder Bisla            92     64
# 5304  2013_37      Michael Hussey            95     59
# 5540  2013_51         Virat Kohli            93     51
# 5579  2013_54        Suresh Raina            99     55
# 5624  2013_57         Virat Kohli            99     59
# 6309  2014_29       Glenn Maxwell            90     40
# 6325   2014_3       Glenn Maxwell            95     48
# 6650  2014_50        David Warner            90     46
# 6737  2014_56      Corey Anderson            95     46
# 6814  2014_60       Manish Pandey            94     52
# 6863   2014_9       Glenn Maxwell            95     44
# 6878   2015_1        Rohit Sharma            98     66
# 7048  2015_20        David Warner            91     55
# 7305  2015_36      Ajinkya Rahane            91     56
# 7532   2015_5         Chris Gayle            96     57
# 7792  2016_12        David Warner            90     61
# 8019  2016_27        David Warner            92     52
# 8320  2016_46         Hashim Amla            96     56
# 8528  2016_59        David Warner            93     59
# 8592   2016_8      Gautam Gambhir            90     62
# 8786  2017_19         Manan Vohra            95     52
# 8957   2017_3          Chris Lynn            93     46
# 9136  2017_40      Rahul Tripathi            93     54
# 9154  2017_41        Rishabh Pant            97     44
# 9282  2017_49        Shreyas Iyer            96     57
# 9316  2017_50     Wriddhiman Saha            93     59

# %%
#finding dismissal of all match
dismissal=dataset1.groupby(['match_id','batsman'])['dismissal_kind'].count().reset_index()
dismissal.drop('match_id',axis=1)
dismissal['batsman_']=dismissal['batsman']
dismissal=dismissal.rename(columns={'match_id':'matchid__'})
dismissal=dismissal.rename(columns={'batsman':'batsman:'}) 
dismissal.head()
# Out:
#   matchid__           batsman:  dismissal_kind           batsman_
# 0    2008_1      Ashley Noffke               1      Ashley Noffke
# 1    2008_1  Balachandra Akhil               1  Balachandra Akhil
# 2    2008_1   Brendon McCullum               0   Brendon McCullum
# 3    2008_1      Cameron White               1      Cameron White
# 4    2008_1       David Hussey               1       David Hussey

# %%
# joining dismissal column with batsman
batsman1 = pd.concat([batsman1, dismissal], axis=1, join='inner')
batsman1=batsman1.drop('matchid__',axis=1)
batsman1=batsman1.drop('batsman:',axis=1)
batsman1=batsman1.drop('batsman_',axis=1)
batsman1.head()
# Out:
#   match_id            batsman  batsman_runs  balls  dismissal_kind
# 0   2008_1      Ashley Noffke             9     12               1
# 1   2008_1  Balachandra Akhil             0      2               1
# 2   2008_1   Brendon McCullum           158     77               0
# 3   2008_1      Cameron White             6     10               1
# 4   2008_1       David Hussey            12     12               1

# %%
#batsman total runs
batsmantotal=dataset1.groupby(['batsman'])['batsman_runs'].sum().reset_index()

# %%
#batsmantotal balls
batsmantotalballs=dataset1.groupby(['batsman_'])['batsman'].count().reset_index()
batsmantotalballs=batsmantotalballs.rename(columns={'batsman':'balls'})

# %%
#joining batsman balls and runs
temp = pd.concat([batsmantotal, batsmantotalballs], axis=1, join='inner')

# %%
#total runs and balls for all batsman
temp=temp.drop('batsman_',axis=1)

temp.head()
# Out:
#             batsman  batsman_runs  balls
# 0    AB De Villiers          3486   2402
# 1     Aakash Chopra            53     75
# 2       Aaron Finch          1604   1270
# 3      Abdur Razzak             0      2
# 4  Abhimanyu Mithun            34     26

# %%
#finding strike rate
temp['strike rate']= temp['batsman_runs']/temp['balls']*100

# %%
#finding total innings
temp2=dataset1.groupby(['match_id','batsman'])['is_super_over'].sum().reset_index()

temp3=dataset1.groupby(['match_id','bowler'])['is_super_over'].sum().reset_index()

temp2_=temp2['batsman'].value_counts().reset_index()

temp3_=temp3['bowler'].value_counts().reset_index()

# %%
# merging innings column to batsman dataset
temp2_=temp2_.rename(columns={'batsman':'innings'})
temp4=pd.merge(temp,temp2_,left_on='batsman',right_on='index',how='left')

# %%
temp4=temp4.drop('index',axis=1)
temp4.head()
# Out:
#             batsman  batsman_runs  balls  strike rate  innings
# 0    AB De Villiers          3486   2402   145.129059      118
# 1     Aakash Chopra            53     75    70.666667        6
# 2       Aaron Finch          1604   1270   126.299213       64
# 3      Abdur Razzak             0      2     0.000000        1
# 4  Abhimanyu Mithun            34     26   130.769231        6

# %%
#adding no. of times out and avg columnn
batsman___=batsman1.groupby(['batsman'])['dismissal_kind'].sum().reset_index()
batsman___=pd.merge(temp4,batsman___, left_on='batsman',right_on='batsman',how='inner')
batsman___=batsman___.rename(columns={'dismissal_kind':'no._of_times_out'})
batsman___['average']=batsman___['batsman_runs']/batsman___['no._of_times_out']
batsman___.head()
# Out:
#             batsman  batsman_runs  balls  strike rate  innings  \
# 0    AB De Villiers          3486   2402   145.129059      118
# 1     Aakash Chopra            53     75    70.666667        6
# 2       Aaron Finch          1604   1270   126.299213       64
# 3      Abdur Razzak             0      2     0.000000        1
# 4  Abhimanyu Mithun            34     26   130.769231        6
#
#    no._of_times_out    average
# 0                85  41.011765
# 1                 5  10.600000
# 2                58  27.655172
# 3                 0        NaN
# 4                 5   6.800000

# %%
#highest of individual batsman
highest=batsman1.groupby(['batsman'])['batsman_runs'].max().reset_index()
highest=highest.rename(columns={'batsman_runs':'highest'})
highest.head()
# Out:
#             batsman  highest
# 0    AB De Villiers      133
# 1     Aakash Chopra       24
# 2       Aaron Finch       88
# 3      Abdur Razzak        0
# 4  Abhimanyu Mithun       11

# %%
#adding highest column
batsman___=pd.merge(batsman___,highest,left_on='batsman',right_on='batsman',how='inner')
batsman___.head()
# Out:
#             batsman  batsman_runs  balls  strike rate  innings  \
# 0    AB De Villiers          3486   2402   145.129059      118
# 1     Aakash Chopra            53     75    70.666667        6
# 2       Aaron Finch          1604   1270   126.299213       64
# 3      Abdur Razzak             0      2     0.000000        1
# 4  Abhimanyu Mithun            34     26   130.769231        6
#
#    no._of_times_out    average  highest
# 0                85  41.011765      133
# 1                 5  10.600000       24
# 2                58  27.655172       88
# 3                 0        NaN        0
# 4                 5   6.800000       11

# %%
# no of times hundreds by all batsman
hundreds
hundreds_=hundreds['batsman'].value_counts().reset_index()
hundreds_.head()
# Out:
#             index  batsman
# 0     Chris Gayle        5
# 1    David Warner        3
# 2     Virat Kohli        3
# 3  AB De Villiers        3
# 4     Hashim Amla        2

# %%
#merging hundreds column to batsman
batsman___1=pd.merge(batsman___,hundreds_,left_on='batsman',right_on='index',how='outer')
batsman___1=batsman___1.rename(columns={'batsman_x':'batsman','batsman_y':'hundreds'})
batsman=batsman___1.drop('index',axis=1)
batsman.head()
# Out:
#             batsman  batsman_runs  balls  strike rate  innings  \
# 0    AB De Villiers          3486   2402   145.129059      118
# 1     Aakash Chopra            53     75    70.666667        6
# 2       Aaron Finch          1604   1270   126.299213       64
# 3      Abdur Razzak             0      2     0.000000        1
# 4  Abhimanyu Mithun            34     26   130.769231        6
#
#    no._of_times_out    average  highest  hundreds
# 0                85  41.011765      133       3.0
# 1                 5  10.600000       24       NaN
# 2                58  27.655172       88       NaN
# 3                 0        NaN        0       NaN
# 4                 5   6.800000       11       NaN

# %%
# no. of fifties by all batsman
fifties_=fifties['batsman'].value_counts().reset_index()

# %%
#merging 50s column to batsman
batsman___1=pd.merge(batsman___,fifties_,left_on='batsman',right_on='index',how='outer')
batsman___1
batsman___1=batsman___1.rename(columns={'batsman_x':'batsman','batsman_y':'fifties'})
batsman11=batsman___1.drop('index',axis=1)
batsman34=pd.merge(batsman,batsman11[['fifties','batsman']],on='batsman')

# %%
#sixes and fours
sixes=dataset1.groupby('batsman')['batsman_runs'].agg(lambda x: (x==4).sum()).reset_index()
fours=dataset1.groupby(['batsman'])['batsman_runs'].agg(lambda x: (x==6).sum()).reset_index()
batsman34['6s'] = sixes['batsman_runs']
batsman34['4s'] = fours['batsman_runs']

# %% [markdown]
# ## Complete batting record of all the players

# %%
#complete record of all the batsman
batsman=batsman34
batsman
# Out:
#                      batsman  batsman_runs  balls  strike rate  innings  \
# 0             AB De Villiers          3486   2402   145.129059      118
# 1              Aakash Chopra            53     75    70.666667        6
# 2                Aaron Finch          1604   1270   126.299213       64
# 3               Abdur Razzak             0      2     0.000000        1
# 4           Abhimanyu Mithun            34     26   130.769231        6
# 5             Abhinav Mukund            19     23    82.608696        2
# 6      Abhishek Jhunjhunwala           217    218    99.541284       15
# 7             Abhishek Nayar           672    588   114.285714       50
# 8              Abhishek Raut           194    172   112.790698       16
# 9                 Abu Nechim            36     27   133.333333        6
# 10            Adam Gilchrist          2069   1555   133.054662       80
# 11                Adam Milne             7     12    58.333333        3
# 12                Adam Voges           181    143   126.573427        7
# 13                Adam Zampa             5      8    62.500000        2
# 14               Aditya Dole            34     23   147.826087        2
# 15               Aditya Tare           339    285   118.947368       27
# 16             Adrian Barath            42     43    97.674419        3
# 17            Aiden Blizzard           120     91   131.868132        7
# 18            Ajantha Mendis             3      6    50.000000        3
# 19            Ajinkya Rahane          3057   2602   117.486549      105
# 20              Ajit Agarkar           179    160   111.875000       18
# 21             Ajit Chandila             4      7    57.142857        2
# 22             Akshath Reddy           164    167    98.203593       10
# 23             Akshdeep Nath            20     28    71.428571        4
# 24              Albie Morkel           975    712   136.938202       67
# 25            Alfonso Thomas            20     19   105.263158        4
# 26               Ali Murtaza            10     14    71.428571        3
# 27             Ambati Rayudu          2416   1964   123.014257      105
# 28               Amit Mishra           340    382    89.005236       49
# 29             Amit Paunikar            49     61    80.327869        5
# ..                       ...           ...    ...          ...      ...
# 431            Usman Khawaja           127    105   120.952381        6
# 432               VVS Laxman           282    271   104.059041       20
# 433              Varun Aaron            46     56    82.142857        9
# 434        Veer Pratap Singh             0      1     0.000000        1
# 435            Venugopal Rao           985    865   113.872832       52
# 436  Vidyut Sivaramakrishnan           145    115   126.086957        8
# 437            Vijay Shankar           101     77   131.168831        4
# 438                Vijay Zol            29     26   111.538462        2
# 439             Vikram Singh             4      3   133.333333        2
# 440   Vikramjeet Singh Malik             7      7   100.000000        2
# 441         Vikrant Yeligati             2      2   100.000000        1
# 442              Vinay Kumar           304    285   106.666667       41
# 443              Virat Kohli          4423   3494   126.588437      141
# 444          Virender Sehwag          2728   1833   148.827059      104
# 445             Vishnu Vinod            19     26    73.076923        3
# 446        Washington Sunder             9     12    75.000000        5
# 447             Wasim Jaffer           130    129   100.775194        8
# 448            Wayne Parnell            63     80    78.750000       12
# 449              Wilkin Mota            56     76    73.684211        8
# 450          Wriddhiman Saha          1557   1219   127.727646       78
# 451            Yashpal Singh            47     67    70.149254        4
# 452                Yo Mahesh            15     28    53.571429        5
# 453             Yogesh Nagar           285    271   105.166052       20
# 454          Yogesh Takawale           192    183   104.918033       10
# 455              Younis Khan             3      7    42.857143        1
# 456            Yusuf Abdulla             0      1     0.000000        1
# 457             Yusuf Pathan          2922   2076   140.751445      133
# 458             Yuvraj Singh          2591   2050   126.390244      116
# 459         Yuzvendra Chahal            15     29    51.724138        8
# 460              Zaheer Khan           117    141    82.978723       27
#
#      no._of_times_out    average  highest  hundreds  fifties   6s   4s
# 0                  85  41.011765      133       3.0     23.0  287  158
# 1                   5  10.600000       24       NaN      NaN    7    0
# 2                  58  27.655172       88       NaN     13.0  170   59
# 3                   0        NaN        0       NaN      NaN    0    0
# 4                   5   6.800000       11       NaN      NaN    4    1
# 5                   2   9.500000       19       NaN      NaN    1    0
# 6                  14  15.500000       53       NaN      1.0   19    5
# 7                  39  17.230769       45       NaN      NaN   55   20
# 8                  11  17.636364       36       NaN      NaN   13    7
# 9                   1  36.000000       18       NaN      NaN    4    1
# 10                 76  27.223684      109       2.0     11.0  239   92
# 11                  3   2.333333        5       NaN      NaN    0    0
# 12                  6  30.166667       45       NaN      NaN   15    3
# 13                  2   2.500000        5       NaN      NaN    1    0
# 14                  2  17.000000       30       NaN      NaN    3    1
# 15                 24  14.125000       59       NaN      1.0   40   11
# 16                  2  21.000000       33       NaN      NaN    5    1
# 17                  7  17.142857       51       NaN      1.0   21    2
# 18                  2   1.500000        2       NaN      NaN    0    0
# 19                 91  33.593407      103       1.0     25.0  320   60
# 20                  8  22.375000       39       NaN      NaN   13    5
# 21                  1   4.000000        4       NaN      NaN    0    0
# 22                 10  16.400000       42       NaN      NaN   15    2
# 23                  4   5.000000       12       NaN      NaN    1    0
# 24                 40  24.375000       73       NaN      3.0   61   55
# 25                  2  10.000000       12       NaN      NaN    1    1
# 26                  1  10.000000        5       NaN      NaN    1    0
# 27                 88  27.454545       81       NaN     14.0  205   79
# 28                 28  12.142857       31       NaN      NaN   27    5
# 29                  5   9.800000       20       NaN      NaN    9    0
# ..                ...        ...      ...       ...      ...  ...  ...
# 431                 5  25.400000       30       NaN      NaN   14    3
# 432                16  17.625000       52       NaN      1.0   33    5
# 433                 3  15.333333       17       NaN      NaN    2    2
# 434                 1   0.000000        0       NaN      NaN    0    0
# 435                42  23.452381       71       NaN      3.0   77   37
# 436                 8  18.125000       54       NaN      1.0   21    3
# 437                 2  50.500000       63       NaN      1.0   12    1
# 438                 2  14.500000       16       NaN      NaN    3    1
# 439                 1   4.000000        4       NaN      NaN    1    0
# 440                 1   7.000000        6       NaN      NaN    1    0
# 441                 1   2.000000        2       NaN      NaN    0    0
# 442                26  11.692308       26       NaN      NaN   20    9
# 443               126  35.103175      113       3.0     31.0  384  160
# 444                98  27.836735      122       2.0     16.0  334  106
# 445                 3   6.333333        9       NaN      NaN    1    1
# 446                 0        inf        5       NaN      NaN    0    0
# 447                 7  18.571429       50       NaN      1.0   14    3
# 448                 9   7.000000       16       NaN      NaN    4    1
# 449                 5  11.200000       25       NaN      NaN    2    0
# 450                63  24.714286      115       1.0      6.0  130   57
# 451                 4  11.750000       20       NaN      NaN    5    0
# 452                 2   7.500000        6       NaN      NaN    0    0
# 453                15  19.000000       44       NaN      NaN   20    9
# 454                 8  24.000000       45       NaN      NaN   26    3
# 455                 1   3.000000        3       NaN      NaN    0    0
# 456                 0        NaN        0       NaN      NaN    0    0
# 457                99  29.515152      100       NaN     14.0  240  149
# 458               100  25.910000       83       NaN     12.0  205  141
# 459                 2   7.500000        4       NaN      NaN    0    0
# 460                15   7.800000       23       NaN      NaN   11    2
#
# [461 rows x 12 columns]

# %% [markdown]
# ## Top 10 run scorers

# %%
plt.subplots(figsize=(10,6))
max_runs=dataset1.groupby(['batsman'])['batsman_runs'].sum()
ax=max_runs.sort_values(ascending=False)[:10].plot.bar(width=0.8,color='b')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.2, p.get_height()+4),fontsize=13)
plt.show()

# %% [markdown]
# ## Maximum no. of 6s

# %%
plt.subplots(figsize=(10,6))
max_runs=batsman.groupby(['batsman'])['6s'].sum()
ax=max_runs.sort_values(ascending=False)[:10].plot.bar(width=0.8,color='r')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.2, p.get_height()+4),fontsize=13)
plt.show()

# %% [markdown]
# ## Bowling Analysis

# %%
#runs and extra runs given by a bowler
bowler=dataset1.groupby(['bowler'])['batsman_runs'].sum().reset_index()
bowler1=dataset1.groupby(['bowler'])['extra_runs'].sum().reset_index()
bowler_=pd.merge(bowler,bowler1,on='bowler')
bowler_.head()
# Out:
#                   bowler  batsman_runs  extra_runs
# 0            Aaron Finch            66           1
# 1        Aavishkar Salvi           190          15
# 2           Abdur Razzak            23           6
# 3       Abhimanyu Mithun           448          29
# 4  Abhishek Jhunjhunwala           126           4

# %%
#total runs given by a bowler
bowler_['runs']=bowler_['batsman_runs']+bowler_['extra_runs']
bowler_=bowler_.drop('batsman_runs',axis=1)
bowler_=bowler_.drop('extra_runs',axis=1)

# %%
bowler_.head()
# Out:
#                   bowler  runs
# 0            Aaron Finch    67
# 1        Aavishkar Salvi   205
# 2           Abdur Razzak    29
# 3       Abhimanyu Mithun   477
# 4  Abhishek Jhunjhunwala   130

# %%
#total balls bowled by bowler
bowlerballs=dataset1.groupby(['bowler'])['batsman_runs'].count().reset_index()
bowlerballs=bowlerballs.rename(columns={'batsman_runs':'balls'})

# %%
bowler=pd.merge(bowler_,bowlerballs[['bowler' ,'balls']],on='bowler')
bowler.head()
# Out:
#                   bowler  runs  balls
# 0            Aaron Finch    67     44
# 1        Aavishkar Salvi   205    156
# 2           Abdur Razzak    29     14
# 3       Abhimanyu Mithun   477    312
# 4  Abhishek Jhunjhunwala   130     88

# %%
#bowler wickets
data=dataset1[dataset1['dismissal_kind']!='run out']
bowlerwickets=data.groupby(['bowler'])['dismissal_kind'].count().reset_index()
bowlerwickets.head()
# Out:
#                   bowler  dismissal_kind
# 0            Aaron Finch               1
# 1        Aavishkar Salvi               7
# 2           Abdur Razzak               0
# 3       Abhimanyu Mithun               7
# 4  Abhishek Jhunjhunwala               1

# %%
#adding wickets column 
bowler=pd.merge(bowler,bowlerwickets[['bowler' ,'dismissal_kind']],on='bowler')
bowler=bowler.rename(columns={'dismissal_kind':'wickets'})
bowler.head()
# Out:
#                   bowler  runs  balls  wickets
# 0            Aaron Finch    67     44        1
# 1        Aavishkar Salvi   205    156        7
# 2           Abdur Razzak    29     14        0
# 3       Abhimanyu Mithun   477    312        7
# 4  Abhishek Jhunjhunwala   130     88        1

# %% [markdown]
# ## Complete bowling record of all the players

# %%
#Bowling record of all bowlers
bowler['economy']=bowler['runs']/bowler['balls']*(6)
bowler['average']=bowler['runs']/bowler['wickets']
bowler['strike rate']=bowler['balls']/bowler['wickets']
bowler
# Out:
#                       bowler  runs  balls  wickets    economy     average  \
# 0                Aaron Finch    67     44        1   9.136364   67.000000
# 1            Aavishkar Salvi   205    156        7   7.884615   29.285714
# 2               Abdur Razzak    29     14        0  12.428571         inf
# 3           Abhimanyu Mithun   477    312        7   9.173077   68.142857
# 4      Abhishek Jhunjhunwala   130     88        1   8.863636  130.000000
# 5             Abhishek Nayar   323    239        9   8.108787   35.888889
# 6              Abhishek Raut    45     30        0   9.000000         inf
# 7                 Abrar Kazi    21     13        0   9.692308         inf
# 8                 Abu Nechim   515    362       12   8.535912   42.916667
# 9             Adam Gilchrist     0      1        1   0.000000    0.000000
# 10                Adam Milne   185    115        4   9.652174   46.250000
# 11                Adam Voges    76     56        0   8.142857         inf
# 12                Adam Zampa   281    225       19   7.493333   14.789474
# 13               Aditya Dole   114     73        5   9.369863   22.800000
# 14            Ajantha Mendis   306    248        8   7.403226   38.250000
# 15            Ajinkya Rahane     5      6        1   5.000000    5.000000
# 16              Ajit Agarkar  1174    820       29   8.590244   40.482759
# 17             Ajit Chandila   245    234       11   6.282051   22.272727
# 18              Albie Morkel  2409   1807       85   7.998893   28.341176
# 19            Alfonso Thomas   416    327       14   7.633028   29.714286
# 20               Ali Murtaza   322    269        9   7.182156   35.777778
# 21               Amit Mishra  3305   2703      134   7.336293   24.664179
# 22                Amit Singh   639    486       28   7.888889   22.821429
# 23               Amit Uniyal    67     38        2  10.578947   33.500000
# 24               Anand Rajan   206    162        8   7.629630   25.750000
# 25                 Andre Nel    31     18        1  10.333333   31.000000
# 26             Andre Russell   917    651       31   8.451613   29.580645
# 27           Andrew Flintoff   106     66        2   9.636364   53.000000
# 28           Andrew McDonald   263    188       11   8.393617   23.909091
# 29            Andrew Symonds   694    540       20   7.711111   34.700000
# ..                       ...   ...    ...      ...        ...         ...
# 325     Tillakaratne Dilshan   368    275        5   8.029091   73.600000
# 326              Tim Southee   930    691       22   8.075253   42.272727
# 327       Tirumalsetti Suman   198    152        6   7.815789   33.000000
# 328              Travis Head    81     48        2  10.125000   40.500000
# 329              Trent Boult   500    355       15   8.450704   33.333333
# 330              Tymal Mills   157    111        5   8.486486   31.400000
# 331          Tyron Henderson    41     36        1   6.833333   41.000000
# 332                 Umar Gul   198    153       12   7.764706   16.500000
# 333              Umesh Yadav  2802   2033       91   8.269552   30.791209
# 334              Varun Aaron  1250    904       38   8.296460   32.894737
# 335        Veer Pratap Singh   300    211       10   8.530806   30.000000
# 336            Venugopal Rao   338    222        6   9.135135   56.333333
# 337  Vidyut Sivaramakrishnan    22     13        1  10.153846   22.000000
# 338            Vijay Shankar    19      6        0  19.000000         inf
# 339             Vikram Singh   549    371       12   8.878706   45.750000
# 340   Vikramjeet Singh Malik   268    212        6   7.584906   44.666667
# 341         Vikrant Yeligati    61     32        0  11.437500         inf
# 342              Vinay Kumar  2976   2161      103   8.262841   28.893204
# 343              Virat Kohli   371    264        4   8.431818   92.750000
# 344          Virender Sehwag   236    138        6  10.260870   39.333333
# 345        Washington Sunder   189    182        8   6.230769   23.625000
# 346            Wayne Parnell   731    601       27   7.297837   27.074074
# 347              Wilkin Mota    98     75        4   7.840000   24.500000
# 348                Yo Mahesh   511    359       21   8.540390   24.333333
# 349             Yogesh Nagar   125     72        4  10.416667   31.250000
# 350            Yusuf Abdulla   311    222       15   8.405405   20.733333
# 351             Yusuf Pathan  1421   1166       41   7.312178   34.658537
# 352             Yuvraj Singh  1068    869       36   7.373993   29.666667
# 353         Yuzvendra Chahal  1600   1219       70   7.875308   22.857143
# 354              Zaheer Khan  2860   2276      103   7.539543   27.766990
#
#      strike rate
# 0      44.000000
# 1      22.285714
# 2            inf
# 3      44.571429
# 4      88.000000
# 5      26.555556
# 6            inf
# 7            inf
# 8      30.166667
# 9       1.000000
# 10     28.750000
# 11           inf
# 12     11.842105
# 13     14.600000
# 14     31.000000
# 15      6.000000
# 16     28.275862
# 17     21.272727
# 18     21.258824
# 19     23.357143
# 20     29.888889
# 21     20.171642
# 22     17.357143
# 23     19.000000
# 24     20.250000
# 25     18.000000
# 26     21.000000
# 27     33.000000
# 28     17.090909
# 29     27.000000
# ..           ...
# 325    55.000000
# 326    31.409091
# 327    25.333333
# 328    24.000000
# 329    23.666667
# 330    22.200000
# 331    36.000000
# 332    12.750000
# 333    22.340659
# 334    23.789474
# 335    21.100000
# 336    37.000000
# 337    13.000000
# 338          inf
# 339    30.916667
# 340    35.333333
# 341          inf
# 342    20.980583
# 343    66.000000
# 344    23.000000
# 345    22.750000
# 346    22.259259
# 347    18.750000
# 348    17.095238
# 349    18.000000
# 350    14.800000
# 351    28.439024
# 352    24.138889
# 353    17.414286
# 354    22.097087
#
# [355 rows x 7 columns]

# %%
# batsman runs scored w.r.t team win in that match or not
run_win=dataset1.groupby(['match_id','batting_team','batsman'])['batsman_runs'].sum().reset_index()
run_win=pd.merge(run_win,dataset3[['match_id','winner']],on='match_id')
run_win.head()
# Out:
#   match_id batting_team           batsman  batsman_runs winner
# 0   2008_1          KKR  Brendon McCullum           158    KKR
# 1   2008_1          KKR      David Hussey            12    KKR
# 2   2008_1          KKR   Mohammad Hafeez             5    KKR
# 3   2008_1          KKR     Ricky Ponting            20    KKR
# 4   2008_1          KKR    Sourav Ganguly            10    KKR

# %%
#all the matches in which Brendon McCullum scores more than 50 and his team wins
run_win[((run_win['batsman']=='Brendon McCullum')&(run_win['batsman_runs']>50)) &(run_win['batting_team']==run_win['winner'])]
# Out:
#      match_id batting_team           batsman  batsman_runs winner
# 0      2008_1          KKR  Brendon McCullum           158    KKR
# 1542  2009_49          KKR  Brendon McCullum            81    KKR
# 2537  2010_56          KKR  Brendon McCullum            57    KKR
# 2733  2011_13          KTK  Brendon McCullum            81    KTK
# 4406  2012_50          KKR  Brendon McCullum            56    KKR
# 6055  2014_13          CSK  Brendon McCullum            71    CSK
# 6194  2014_21          CSK  Brendon McCullum            56    CSK
# 7128  2015_25          CSK  Brendon McCullum            66    CSK
# 7371   2015_4          CSK  Brendon McCullum           100    CSK
# 7467  2015_46          CSK  Brendon McCullum            81    CSK
# 7964  2016_23           GL  Brendon McCullum            60     GL

# %%
len(run_win[((run_win['batsman']=='Rahul Dravid')&(run_win['batsman_runs']>50)) &(run_win['batting_team']==run_win['winner'])])/len(run_win[((run_win['batsman']=='Rahul Dravid')&(run_win['batsman_runs']>50))])*100
# Out:
# 45.45454545454545

# %%
# function that determines winning percentage if a batsman scores more than 50
def winning_per_batsman_scores_50(x):
 print(len(run_win[((run_win['batsman']==x)&(run_win['batsman_runs']>50)) &(run_win['batting_team']==run_win['winner'])])/len(run_win[((run_win['batsman']==x)&(run_win['batsman_runs']>50))])*100)

# %% [markdown]
# ## Chances of winning when different players scores more than 50

# %%
#chances of winning when brendon mccullum scores more than 50
winning_per_batsman_scores_50('Brendon McCullum')
# Out:
# 73.33333333333333

# %%
#chances of winning when MS dhoni scores more than 50
winning_per_batsman_scores_50('Mahendra Singh Dhoni')
# Out:
# 76.47058823529412

# %%
#chances of winning when viru scores more than 50
winning_per_batsman_scores_50('Virender Sehwag')
# Out:
# 70.58823529411765

# %%
#chances of winning when virat scores more than 50
winning_per_batsman_scores_50('Virat Kohli')
# Out:
# 52.94117647058824

# %%
#chances of winning when Chris gayle scores more than 50
winning_per_batsman_scores_50('Chris Gayle')
# Out:
# 66.66666666666666

# %%
#chances of winning when dhawan scores more than 50
winning_per_batsman_scores_50('Shikhar Dhawan')
# Out:
# 56.52173913043478

# %%
#chances of winning when AB scores more than 50
winning_per_batsman_scores_50('AB De Villiers')
# Out:
# 69.56521739130434
